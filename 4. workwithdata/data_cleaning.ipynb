# %%
#Import libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
#Import Data

# %%
data1 = "survey_results_public.csv"

# %%
data2 = "survey_results_schema.csv"

# %%
data_show = pd.read_csv(data1)

# %%
data_show
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
data_show.shape
# Out:
# (65437, 114)

# %%
# 1. 65437 respondenti au completat sondajul.

# %%
data_show.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# 2. 0 respondenti au raspuns la toate intrebarile.

# %%
sdata = data_show.loc[0:, ['WorkExp']]
sdata.dropna().agg({'WorkExp':['average', 'median']})
# Out:
#            WorkExp
# average  11.466957
# median    9.000000

# %%
sdata.dropna().mode()
# Out:
#    WorkExp
# 0      3.0

# %%
# 3. Average, median and mode for WorkExp.

# %%
data_show[data_show['RemoteWork'] == 'Remote']
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 6               7  I am not primarily a developer, but I write co...
# 9              10                     I am a developer by profession
# ...           ...                                                ...
# 65421       65422                     I am a developer by profession
# 65424       65425                     I am a developer by profession
# 65428       65429                     I am a developer by profession
# 65432       65433                     I am a developer by profession
# 65433       65434                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
# 4. 20831 respondenti lucreaza remote.

# %%
data_show['py_coders']=data_show.LanguageHaveWorkedWith.str.contains('python', case=False,na=False)
pyth_users = round(data_show.py_coders.sum())
print(f"Number of Python coders: {pyth_users}")
# Out:
# Number of Python coders: 30795

# %%
# 5. 30795 respondenti programeaza in Python.

# %%
learning_sources = data_show.loc[0:,['LearnCodeOnline']]

# %%
learning_sources.dropna().count()
# Out:
# LearnCodeOnline    49237
# dtype: int64

# %%
# 6. 49237 respondenti au invatat sa programeze cu ajutorul cursurilor online.

# %%
# Create clean sub-dataframe with only the information required.

# %%
sdf = data_show.loc[0:,['LanguageHaveWorkedWith','Country','ConvertedCompYearly']]
py_sdf=sdf[(sdf['LanguageHaveWorkedWith'].str.contains('Python', na=False)) == True]
csdf = py_sdf.dropna()

# %%
# Salary tabel/ country

# %%
grouped_df = csdf.groupby('Country').agg({'ConvertedCompYearly':['mean', 'median']})
grouped_df
# Out:
#                                      ConvertedCompYearly
#                                                     mean    median
# Country
# Afghanistan                                  4543.000000    4768.5
# Albania                                     56295.000000   56295.0
# Algeria                                      9053.285714    6230.0
# Andorra                                    193331.000000  193331.0
# Angola                                          6.000000       6.0
# ...                                                  ...       ...
# Venezuela, Bolivarian Republic of...        21500.000000    7100.0
# Viet Nam                                    14014.562500   10180.0
# Yemen                                       10297.333333    5333.0
# Zambia                                      28123.666667   22803.0
# Zimbabwe                                    37500.000000   18000.0
#
# [151 rows x 2 columns]

# %%
# 7. Table above.

# %%
sdf2 = data_show.loc[0:,['ConvertedCompYearly','EdLevel']]
csdf2 = sdf2.dropna()

# %%
csdf2.sort_values('ConvertedCompYearly', ascending = False).head(5)
# Out:
#        ConvertedCompYearly                                         EdLevel
# 15837           16256603.0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12723           13818022.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 28379            9000000.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 17593            6340564.0    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17672            4936778.0  Professional degree (JD, MD, Ph.D, Ed.D, etc.)

# %%
# 8. Education level of top 5 paid respondents.

# %%
# Create clean dataset.

# %%
bsdf = data_show.loc[0:,['ResponseId', 'Age','LanguageHaveWorkedWith', 'py_coders']]
bcsdf = bsdf.dropna()

# %%
grouped_bdf = bcsdf.groupby('Age', as_index=False).agg({'ResponseId': 'count', 'py_coders': 'sum'})
grouped_bdf['perc_pyth'] = round((grouped_bdf['py_coders'] / grouped_bdf['ResponseId']) * 100, 2)
grouped_bdf
# Out:
#                   Age  ResponseId  py_coders  perc_pyth
# 0     18-24 years old       12432       7884      63.42
# 1     25-34 years old       21755      10945      50.31
# 2     35-44 years old       13909       6204      44.60
# 3     45-54 years old        5910       2619      44.31
# 4     55-64 years old        2453       1041      42.44
# 5   65 years or older         710        290      40.85
# 6   Prefer not to say         257        146      56.81
# 7  Under 18 years old        2319       1666      71.84

# %%
# b1. Percentage of Python coders per age group.

# %%
# Create clean dataset.

# %%
bsdf2 = data_show.loc[0:,['RemoteWork','Industry','ConvertedCompYearly']]
bsdf2 = bsdf2[bsdf2['RemoteWork'] == 'Remote']
bcsdf2 = bsdf2.dropna()
bcsdf2
# Out:
#       RemoteWork                              Industry  ConvertedCompYearly
# 379       Remote  Computer Systems Design and Services              91295.0
# 389       Remote       Transportation, or Supply Chain             110000.0
# 398       Remote                            Healthcare             195000.0
# 415       Remote                  Software Development              79481.0
# 416       Remote                                Other:             170000.0
# ...          ...                                   ...                  ...
# 41160     Remote                  Software Development              17945.0
# 41161     Remote          Media & Advertising Services              50000.0
# 41164     Remote                      Higher Education              94000.0
# 41173     Remote                               Fintech              23256.0
# 41174     Remote                  Software Development               9571.0
#
# [6479 rows x 3 columns]

# %%
# Find the 75th percentile.

# %%
bcsdf2['ConvertedCompYearly'].quantile(.75)
# Out:
# 129333.0

# %%
# 75th percentile workers dataset.

# %%
bcsdf2_pct = bcsdf2[bcsdf2['ConvertedCompYearly'] >= 129333.0]
bcsdf2_pct
# Out:
#       RemoteWork              Industry  ConvertedCompYearly
# 398       Remote            Healthcare             195000.0
# 416       Remote                Other:             170000.0
# 428       Remote  Software Development             230000.0
# 432       Remote  Software Development             160000.0
# 443       Remote                Other:             161783.0
# ...          ...                   ...                  ...
# 41128     Remote             Insurance             152865.0
# 41134     Remote               Fintech             150000.0
# 41141     Remote  Software Development             220000.0
# 41142     Remote               Fintech             200000.0
# 41149     Remote  Software Development             145000.0
#
# [1620 rows x 3 columns]

# %%
# Arrange dataset based on popularity of industry.

# %%
counts = bcsdf2_pct.groupby('Industry').count()
sorted_bcsdf2_pct = counts.sort_values('ConvertedCompYearly', ascending = False)
sorted_bcsdf2_pct
# Out:
#                                             RemoteWork  ConvertedCompYearly
# Industry
# Software Development                               591                  591
# Other:                                             175                  175
# Fintech                                            127                  127
# Healthcare                                         118                  118
# Internet, Telecomm or Information Services         107                  107
# Retail and Consumer Services                        86                   86
# Media & Advertising Services                        80                   80
# Computer Systems Design and Services                59                   59
# Banking/Financial Services                          52                   52
# Government                                          50                   50
# Transportation, or Supply Chain                     46                   46
# ...

# %%
# Bonus q2. Most popular industries amongs 75th percentile salaried respondents.
